# %%
import urllib.request, urllib.parse, urllib.error
import ssl
import json
import sqlite3
import numpy as np
import pandas as pd
import pymongo
#import bson import json_util
from pymongo import MongoClient
import ssl
#import request

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/g7/rr61ybj96m75tn_77cvl7fv00000gn/T/ipykernel_8260/3661060248.py in <module>
#       9 from pymongo import MongoClient
#      10 import ssl
# ---> 11 import request
#      12
#      13 ssl._create_default_https_context = ssl._create_unverified_context
#
# ModuleNotFoundError: No module named 'request'

# %%
#script to insert dataset into MongoDB

API_KEY = 'KALC52P2HYWJCURY'
Symbol = 'CLOV'
Interval = 15
url = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol={Symbol}&interval={Interval}min&slice=year1month1&apikey={API_KEY}"
stockdata = urllib.request.urlopen(url)
data = stockdata.read().decode()
data = [row.strip().split(',') for row in data.split('\n')]
df = pd.DataFrame(data[1:-1], columns=data[0])
client = MongoClient('mongodb+srv://edwardsanchez001:Strake12345@cluster0.jvjek.mongodb.net/myFirstDatabase?retryWrites=true&?ssl=true&ssl_cert_reqs=CERT_NONE&w=majority')
records = json.loads(df.T.to_json()).values()
db.CLOV_collection.insert_many(records)

# %%
API_KEY = 'KALC52P2HYWJCURY'
Symbol = 'WISH'
Interval = 15
"""
#this first URL is a JSON file
url = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={Symbol}&apikey={API_KEY}"
stockdata = urllib.request.urlopen(url)
data = stockdata.read().decode()
js = json.loads(data)
js
"""
# Out:
# '\n#this first URL is a JSON file\nurl = f"https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol={Symbol}&apikey={API_KEY}"\nstockdata = urllib.request.urlopen(url)\ndata = stockdata.read().decode()\njs = json.loads(data)\njs\n'

# %%
url = f"https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol={Symbol}&interval={Interval}min&slice=year1month1&apikey={API_KEY}"
stockdata = urllib.request.urlopen(url)
data = stockdata.read().decode()
data
# Out:
# 'time,open,high,low,close,volume\r\n2021-07-08 20:00:00,11.05,11.09,11.04,11.06,18018\r\n2021-07-08 19:45:00,11.05,11.09,11.02,11.06,8409\r\n2021-07-08 19:30:00,11.1,11.1,11.06,11.1,33217\r\n2021-07-08 19:15:00,11.15,11.16,11.07,11.1,38525\r\n2021-07-08 19:00:00,11.03,11.16,11.03,11.1,52819\r\n2021-07-08 18:45:00,11.03,11.04,11.0,11.03,11763\r\n2021-07-08 18:30:00,10.98,11.06,10.98,11.04,56021\r\n2021-07-08 18:15:00,10.98,10.98,10.93,10.98,21299\r\n2021-07-08 18:00:00,10.95,10.98,10.93,10.98,26681\r\n2021-07-08 17:45:00,10.99,10.99,10.95,10.95,32756\r\n2021-07-08 17:30:00,10.95,10.99,10.93,10.965,100713\r\n2021-07-08 17:15:00,10.9,10.96,10.88,10.96,70604\r\n2021-07-08 17:00:00,10.92,10.93,10.89,10.9,33043\r\n2021-07-08 16:45:00,10.92,10.93,10.87,10.92,94662\r\n2021-07-08 16:30:00,10.9,10.94,10.86,10.92,58595\r\n2021-07-08 16:15:00,11.0,11.0,10.86,10.93,178201\r\n2021-07-08 16:00:00,10.98,11.0,10.9,10.99,2677964\r\n2021-07-08 15:45:00,10.99,11.03,10.93,10.98,1200705\r\n2021-07-08 15:3
# ...

# %%
#for the first JSON URL
#df=pd.DataFrame(js['Time Series (Daily)']).T

# %%
#response = requests.get(base_url, params=params)

# %%
# convert text data in to a list of of list
data = [row.strip().split(',') for row in data.split('\n')]
data
# Out:
# [['time', 'open', 'high', 'low', 'close', 'volume'],
#  ['2021-07-08 20:00:00', '11.05', '11.09', '11.04', '11.06', '18018'],
#  ['2021-07-08 19:45:00', '11.05', '11.09', '11.02', '11.06', '8409'],
#  ['2021-07-08 19:30:00', '11.1', '11.1', '11.06', '11.1', '33217'],
#  ['2021-07-08 19:15:00', '11.15', '11.16', '11.07', '11.1', '38525'],
#  ['2021-07-08 19:00:00', '11.03', '11.16', '11.03', '11.1', '52819'],
#  ['2021-07-08 18:45:00', '11.03', '11.04', '11.0', '11.03', '11763'],
#  ['2021-07-08 18:30:00', '10.98', '11.06', '10.98', '11.04', '56021'],
#  ['2021-07-08 18:15:00', '10.98', '10.98', '10.93', '10.98', '21299'],
#  ['2021-07-08 18:00:00', '10.95', '10.98', '10.93', '10.98', '26681'],
#  ['2021-07-08 17:45:00', '10.99', '10.99', '10.95', '10.95', '32756'],
#  ['2021-07-08 17:30:00', '10.95', '10.99', '10.93', '10.965', '100713'],
#  ['2021-07-08 17:15:00', '10.9', '10.96', '10.88', '10.96', '70604'],
#  ['2021-07-08 17:00:00', '10.92', '10.93', '10.89', '10.9', '33043'],
# ...

# %%
# load data into a dataframe for the CVS file type
df = pd.DataFrame(data[1:-1], columns=data[0])
df

# %%
#For the JSON FILE
#df.rename(columns={'1. open': 'Open',
                  # '2. high': 'High',
                 #  '3. low': 'Low',
                  # '4. close': 'Close',
                 #  '5. volume': 'Volume'}, inplace=True)

# %%
# Out:
#                      time   open   high    low  close   volume
# 0     2021-07-08 20:00:00  11.05  11.09  11.04  11.06    18018
# 1     2021-07-08 19:45:00  11.05  11.09  11.02  11.06     8409
# 2     2021-07-08 19:30:00   11.1   11.1  11.06   11.1    33217
# 3     2021-07-08 19:15:00  11.15  11.16  11.07   11.1    38525
# 4     2021-07-08 19:00:00  11.03  11.16  11.03   11.1    52819
# ...                   ...    ...    ...    ...    ...      ...
# 1339  2021-06-09 05:15:00  16.34  16.35   14.9   15.5  1420259
# 1340  2021-06-09 05:00:00  16.39  16.69   16.3  16.35   401424
# 1341  2021-06-09 04:45:00  16.36   16.9  15.91  16.34   762522
# 1342  2021-06-09 04:30:00  16.06  16.58  15.85  16.35   591451
# 1343  2021-06-09 04:15:00  14.98  17.65  14.98  16.04  1407409
#
# [1344 rows x 6 columns]

# %%
client = MongoClient('mongodb+srv://edwardsanchez001:Strake12345@cluster0.jvjek.mongodb.net/myFirstDatabase?retryWrites=true&?ssl=true&ssl_cert_reqs=CERT_NONE&w=majority') # make the connection local
# Out:
# /Users/edwardsanchez/Ironhack/virtual/venv-web-scraping/lib/python3.9/site-packages/pymongo/common.py:781: UserWarning: Unknown option ?ssl
#   warnings.warn(str(exc))

# %%
#pip install dnspython

# %%
#db = client.stock_db
#SPCE_Collection = db.SPCE_Collection

# %%
records = json.loads(df.T.to_json()).values()
records
# Out:
# dict_values([{'time': '2021-07-08 20:00:00', 'open': '11.05', 'high': '11.09', 'low': '11.04', 'close': '11.06', 'volume': '18018'}, {'time': '2021-07-08 19:45:00', 'open': '11.05', 'high': '11.09', 'low': '11.02', 'close': '11.06', 'volume': '8409'}, {'time': '2021-07-08 19:30:00', 'open': '11.1', 'high': '11.1', 'low': '11.06', 'close': '11.1', 'volume': '33217'}, {'time': '2021-07-08 19:15:00', 'open': '11.15', 'high': '11.16', 'low': '11.07', 'close': '11.1', 'volume': '38525'}, {'time': '2021-07-08 19:00:00', 'open': '11.03', 'high': '11.16', 'low': '11.03', 'close': '11.1', 'volume': '52819'}, {'time': '2021-07-08 18:45:00', 'open': '11.03', 'high': '11.04', 'low': '11.0', 'close': '11.03', 'volume': '11763'}, {'time': '2021-07-08 18:30:00', 'open': '10.98', 'high': '11.06', 'low': '10.98', 'close': '11.04', 'volume': '56021'}, {'time': '2021-07-08 18:15:00', 'open': '10.98', 'high': '10.98', 'low': '10.93', 'close': '10.98', 'volume': '21299'}, {'time': '2021-07-08 18:00:00', 
# ...

# %%
db.WISH_collection.insert_many(records)
#MSFT_collection.insert_many(df)

# %%
list(SPCE_collection.find())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/g7/rr61ybj96m75tn_77cvl7fv00000gn/T/ipykernel_8260/2483255190.py in <module>
# ----> 1 list(SPCE_Collection.find())
#
# NameError: name 'SPCE_Collection' is not defined

# %%
len(list(MSFT_collection.find()))
# Out:
# 100
